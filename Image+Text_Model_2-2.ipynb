# %% [markdown]
# ### การเตรียมข้อมูล

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import os
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input
from transformers import BertTokenizer
import tensorflow as tf

# ฟังก์ชันสำหรับโหลดและประมวลผลรูปภาพ
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = preprocess_input(img_array)
    return img_array

# ฟังก์ชันสำหรับสร้าง image path
def get_image_path(filename, base_path):
    if 1 <= int(filename) <= 292:
        return os.path.join(base_path, 'II', f"{filename}.jpg")
    elif 293 <= int(filename) <= 523:
        return os.path.join(base_path, 'III', f"{filename}.jpg")
    elif 524 <= int(filename) <= 593:
        return os.path.join(base_path, 'IV', f"{filename}.jpg")
    else:
        raise ValueError(f"Invalid filename: {filename}")

# โหลดข้อมูล
df = pd.read_csv('/content/drive/MyDrive/work_space_tunnel/Data_PyMu (csv2).csv')

base_image_path = '/content/drive/MyDrive/work_space_tunnel'

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# สร้าง list เพื่อเก็บข้อมูล
image_data = []
text_data = []
labels = []

# BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
max_length = 512

# วนลูปผ่านแต่ละแถวใน DataFrame
for index, row in df.iterrows():
    filename = str(row['filename'])

    # โหลดและประมวลผลรูปภาพ
    image_path = get_image_path(filename, base_image_path)
    img_array = load_and_preprocess_image(image_path)
    image_data.append(img_array)

    # ประมวลผลข้อความ
    text = ' '.join(row[['select1', 'select2', 'select4', 'select5']].astype(str))
    encoded_text = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='tf'
    )
    text_data.append({
        'input_ids': encoded_text['input_ids'][0],
        'attention_mask': encoded_text['attention_mask'][0]
    })

    # เก็บ label
    labels.append(row['class'])

# แปลงเป็น numpy array
image_data = np.array(image_data)
input_ids = np.array([item['input_ids'] for item in text_data])
attention_masks = np.array([item['attention_mask'] for item in text_data])

import matplotlib.pyplot as plt
import numpy as np

def inspect_image(image_path, target_size=(224, 224)):
    # โหลดและประมวลผลรูปภาพ
    img_array = load_and_preprocess_image(image_path, target_size)

    # ตรวจสอบขนาดของ array
    print(f"Shape of the image array: {img_array.shape}")

    # ตรวจสอบค่าต่ำสุดและสูงสุดหลังจาก preprocessing
    print(f"Min value: {np.min(img_array)}")
    print(f"Max value: {np.max(img_array)}")

    # คำนวณและแสดงค่าเฉลี่ยและส่วนเบี่ยงเบนมาตรฐาน
    print(f"Mean: {np.mean(img_array)}")
    print(f"Standard deviation: {np.std(img_array)}")

    # แสดงรูปภาพ
    plt.figure(figsize=(10, 5))

    # รูปภาพต้นฉบับ
    plt.subplot(1, 2, 1)
    original_img = plt.imread(image_path)
    plt.imshow(original_img)
    plt.title("Original Image")

    # รูปภาพหลัง preprocessing
    plt.subplot(1, 2, 2)
    # ปรับ scale กลับมาให้แสดงผลได้
    img_display = (img_array - np.min(img_array)) / (np.max(img_array) - np.min(img_array))
    plt.imshow(img_display)
    plt.title("Preprocessed Image")

    plt.show()

# ใช้งานฟังก์ชัน
image_path = get_image_path("1", base_image_path)  # เปลี่ยนเป็นรูปภาพที่ต้องการตรวจสอบ
inspect_image(image_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Shape of the image array: (224, 224, 3)
# Min value: -0.7568627595901489
# Max value: 1.0
# Mean: 0.13240087032318115
# Standard deviation: 0.294062077999115

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(f"Input IDs shape: {encoded_text['input_ids'].shape}")
print(f"Attention Mask shape: {encoded_text['attention_mask'].shape}")
print("Decoded text:", tokenizer.decode(encoded_text['input_ids'][0]))
original_length = len(tokenizer.encode(text))
encoded_length = len(encoded_text['input_ids'][0])
print(f"Original length: {original_length}, Encoded length: {encoded_length}")
print("First token:", tokenizer.decode(encoded_text['input_ids'][0][0]))
print("Last token:", tokenizer.decode(encoded_text['input_ids'][0][-1]))
# Out:
# Input IDs shape: (1, 512)
# Attention Mask shape: (1, 512)
# Decoded text: [CLS] tunnel entrance and exit map number : rt - gm - mt - 01 - 0289kilometerslength : 0 + 593. 50land survey certificate no. [UNK]. 21 / 2559 ( land department ) geological mapping ( geological survey ) monk : tunnel axis bearing in the tunnel ( tunnel axis bearing ) … … ….. 0 ( north - south ) … … … …. earth covers the tunnel : 85. 91 m start : 0 + 592. 50 end : 0 + 593. 50 ast time : 15 : 30 applying time : 18 : 00 date : 21 / 10 / 2561 symbols infilling weathering con. soft < 5 mmmoderately weathered. dippingsoft < 5 mmmoderately weathered. wetsoft < 5 mmhighly weathered. dippingj6smoothj340 - 60° / 210 - 230 60 - 200 mm0. 1 - 1 mm1 - 3 m50 - 70° / 170 - 1900. 2 - 0. 6 m1 - 3 m0. 1 - 1 mmsmoothroughnessscontinuity type dip / dip directionspacingpersistenceaperturesmoothj260 - 70° / 110 - 130 60 - 200 mm3 - 4 m0. 1 - 1 mm description of limestone, gray to light gray, fibrous texture showing arrangement, composed of calcite and dolomite, has a moderate rate of weathering. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# Original length: 300, Encoded length: 512
# First token: [ C L S ]
# Last token: [ P A D ]

# %%
# Label Encoder
label_encoder = LabelEncoder()
labels_int  = label_encoder.fit_transform(labels)
labels_onehot  = to_categorical(labels_int)
labels = np.array(labels_onehot)
labels = labels.astype(int)

# คำนวณ class weights
class_weights = compute_class_weight(class_weight='balanced',
                                     classes=np.unique(labels_int),
                                     y=labels_int)
class_weights_dict = dict(enumerate(class_weights))

print(class_weights_dict)
# Out:
# {0: 0.6769406392694064, 1: 0.8556998556998557, 2: 2.823809523809524}

# %%
# สร้าง tf.data.Dataset
dataset = tf.data.Dataset.from_tensor_slices(({
    'image': image_data,
    'input_ids': input_ids,
    'attention_mask': attention_masks
}, labels))

dataset = dataset.shuffle(buffer_size=len(dataset))

# แบ่ง dataset เป็น train, validation, และ test
train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_ds = dataset.take(train_size)
val_ds = dataset.skip(train_size).take(val_size)
test_ds = dataset.skip(train_size + val_size)

batch_size = 32
train_ds = train_ds.batch(batch_size)
val_ds = val_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)

print("Data preparation completed.")
print(f"Train size: {train_size}")
print(f"Validation size: {val_size}")
print(f"Test size: {test_size}")
# Out:
# Data preparation completed.
# Train size: 415
# Validation size: 88
# Test size: 90

# %%
train_ds
# Out:
# <_BatchDataset element_spec=({'image': TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), 'input_ids': TensorSpec(shape=(None, 512), dtype=tf.int32, name=None), 'attention_mask': TensorSpec(shape=(None, 512), dtype=tf.int32, name=None)}, TensorSpec(shape=(None, 3), dtype=tf.int64, name=None))>

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.applications import InceptionResNetV2
from transformers import TFBertModel
from tensorflow.keras.metrics import F1Score

# สร้าง Custom Layer สำหรับ BERT

class BertLayer(tf.keras.layers.Layer):
    def __init__(self, bert_model_name='bert-base-uncased', trainable=True, **kwargs):
        super(BertLayer, self).__init__(**kwargs)
        self.bert_model_name = bert_model_name
        self.trainable = trainable
        self.bert = TFBertModel.from_pretrained(self.bert_model_name)
        self.bert.trainable = self.trainable

    def build(self, input_shape):
        # This ensures the layer's weights are created
        self.bert.build(input_shape)
        super(BertLayer, self).build(input_shape)

    def call(self, inputs):
        input_ids, attention_mask = inputs
        outputs = self.bert(input_ids, attention_mask=attention_mask, return_dict=True)
        return outputs.last_hidden_state

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], input_shape[0][1], self.bert.config.hidden_size)

    def get_config(self):
        config = super().get_config()
        config.update({
            "bert_model_name": self.bert_model_name,
            "trainable": self.trainable,
        })
        return config

    @classmethod
    def from_config(cls, config):
        return cls(**config)





def simplified_multimodal_model(img_height, img_width, max_length, num_classes):
    # Image processing
    image_input = layers.Input(shape=(img_height, img_width, 3), name='image')
    base_model = InceptionResNetV2(weights=None, include_top=False, input_shape=(img_height, img_width, 3))
    base_model.trainable = True
    x_img = base_model(image_input)
    x_img = layers.GlobalAveragePooling2D()(x_img)
    x_img = layers.Dense(64, activation='relu')(x_img)

    # Text processing
    input_ids = layers.Input(shape=(max_length,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(max_length,), dtype=tf.int32, name='attention_mask')
    bert_layer = BertLayer()
    bert_outputs = bert_layer([input_ids, attention_mask])
    cls_token = layers.Lambda(lambda x: x[:, 0, :])(bert_outputs)
    x_text = layers.Dense(64, activation='relu')(cls_token)

    # Combine features
    combined_features = layers.Concatenate()([x_img, x_text])
    x = layers.Dense(32, activation='relu')(combined_features)
    x = layers.Dropout(0.15)(x)
    output = layers.Dense(num_classes, activation='softmax')(x)

    model = Model(
        inputs={'image': image_input, 'input_ids': input_ids, 'attention_mask': attention_mask},
        outputs=output,
        name='simplified_multimodal_model'
    )
    return model

# สร้างโมเดล
img_height, img_width = 224, 224
max_length = 512
num_classes = 3

model = simplified_multimodal_model(img_height, img_width, max_length, num_classes)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy', F1Score()]
)
model.summary()
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Model: "simplified_multimodal_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)        │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_ids (InputLayer)    │ (None, 512)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention_mask            │ (None, 512)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ inception_resnet_v2       │ (None, 5, 5, 1536)     │     54,336,736 │ image[0][0]            │
# │ (Functional)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bert_layer (BertLayer)    │ (None, 512, 768)       │              0 │ input_ids[0][0],       │
# │                           │                        │                │ attention_mask[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1536)           │              0 │ inception_resnet_v2[0… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 768)            │              0 │ bert_layer[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │         98,368 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 64)             │         49,216 │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128)            │              0 │ dense[0][0],           │
# │                           │                        │                │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          4,128 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 32)             │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 3)              │             99 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 54,488,547 (207.86 MB)
#  Trainable params: 54,428,003 (207.63 MB)
#  Non-trainable params: 60,544 (236.50 KB)

# %%
import numpy as np
from tensorflow.keras.callbacks import Callback

class SaveBestValidationAccuracy(Callback):
    def __init__(self, filepath):
        super().__init__()
        self.filepath = filepath
        self.best_val_accuracy = 0

    def on_epoch_end(self, epoch, logs=None):
        current_val_accuracy = logs.get('val_accuracy')
        if current_val_accuracy > self.best_val_accuracy:
            self.best_val_accuracy = current_val_accuracy
            self.model.save_weights(self.filepath)
            print(f"\nSaved model with best validation accuracy: {self.best_val_accuracy:.4f}")

# Usage:
filepath = 'best_model.weights.h5'
save_best_callback = SaveBestValidationAccuracy(filepath)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=80,
    batch_size=batch_size,
    class_weight=class_weights_dict,
    callbacks=[save_best_callback]
)
# Out:
# Epoch 1/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5066 - f1_score: 0.4751 - loss: 0.9899
# Saved model with best validation accuracy: 0.5455
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 299s 10s/step - accuracy: 0.5108 - f1_score: 0.4792 - loss: 0.9853 - val_accuracy: 0.5455 - val_f1_score: 0.2353 - val_loss: 1.3990
# Epoch 2/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 625ms/step - accuracy: 0.6805 - f1_score: 0.6492 - loss: 0.7514 - val_accuracy: 0.1705 - val_f1_score: 0.0971 - val_loss: 58.6578
# Epoch 3/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 620ms/step - accuracy: 0.7101 - f1_score: 0.6763 - loss: 0.6227 - val_accuracy: 0.1136 - val_f1_score: 0.0680 - val_loss: 41.0887
# Epoch 4/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 620ms/step - accuracy: 0.7548 - f1_score: 0.7172 - loss: 0.6093 - val_accuracy: 0.1591 - val_f1_score: 0.0915 - val_loss: 3.7825
# Epoch 5/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 621ms/step - accuracy: 0.7446 - f1_score: 0.7203 - loss: 0.6309 - val_accuracy: 0.1705 - val_f1_score: 0.1726 - val_loss: 2.2493
# Epoch 6/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.8066 - f1_score: 0.7844 - loss: 0.4734 - val_accuracy: 0.2500 - val_f1_score: 0.2412 - val_loss: 1.4025
# Epoch 7/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.8107 - f1_score: 0.7926 - loss: 0.4859
# Saved model with best validation accuracy: 0.6705
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 820ms/step - accuracy: 0.8115 - f1_score: 0.7930 - loss: 0.4829 - val_accuracy: 0.6705 - val_f1_score: 0.5256 - val_loss: 0.7170
# Epoch 8/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 606ms/step - accuracy: 0.8668 - f1_score: 0.8419 - loss: 0.3777 - val_accuracy: 0.4886 - val_f1_score: 0.4584 - val_loss: 1.4273
# Epoch 9/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 607ms/step - accuracy: 0.8595 - f1_score: 0.8336 - loss: 0.3836 - val_accuracy: 0.5568 - val_f1_score: 0.3534 - val_loss: 0.8998
# Epoch 10/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.8311 - f1_score: 0.8118 - loss: 0.3666 - val_accuracy: 0.6705 - val_f1_score: 0.5198 - val_loss: 0.8560
# Epoch 11/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.8814 - f1_score: 0.8582 - loss: 0.3484
# Saved model with best validation accuracy: 0.7727
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 823ms/step - accuracy: 0.8809 - f1_score: 0.8574 - loss: 0.3511 - val_accuracy: 0.7727 - val_f1_score: 0.7253 - val_loss: 0.5964
# Epoch 12/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 0.8753 - f1_score: 0.8751 - loss: 0.2890 - val_accuracy: 0.3068 - val_f1_score: 0.3167 - val_loss: 2.8334
# Epoch 13/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 615ms/step - accuracy: 0.8268 - f1_score: 0.8103 - loss: 0.3827 - val_accuracy: 0.3409 - val_f1_score: 0.3280 - val_loss: 2.0105
# Epoch 14/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.8960 - f1_score: 0.8909 - loss: 0.2947 - val_accuracy: 0.6250 - val_f1_score: 0.4410 - val_loss: 1.1969
# Epoch 15/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.8839 - f1_score: 0.8790 - loss: 0.2544 - val_accuracy: 0.6250 - val_f1_score: 0.5866 - val_loss: 1.5517
# Epoch 16/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.8649 - f1_score: 0.8506 - loss: 0.3411
# Saved model with best validation accuracy: 0.7841
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 833ms/step - accuracy: 0.8665 - f1_score: 0.8519 - loss: 0.3374 - val_accuracy: 0.7841 - val_f1_score: 0.6840 - val_loss: 0.6280
# Epoch 17/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 608ms/step - accuracy: 0.9178 - f1_score: 0.9141 - loss: 0.2260 - val_accuracy: 0.7500 - val_f1_score: 0.6950 - val_loss: 0.8534
# Epoch 18/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.9131 - f1_score: 0.9105 - loss: 0.2324 - val_accuracy: 0.7045 - val_f1_score: 0.6451 - val_loss: 0.7686
# Epoch 19/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.8641 - f1_score: 0.8345 - loss: 0.2750 - val_accuracy: 0.6818 - val_f1_score: 0.6259 - val_loss: 1.1045
# Epoch 20/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.9372 - f1_score: 0.9380 - loss: 0.2165
# Saved model with best validation accuracy: 0.8182
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 830ms/step - accuracy: 0.9360 - f1_score: 0.9369 - loss: 0.2167 - val_accuracy: 0.8182 - val_f1_score: 0.8005 - val_loss: 0.4761
# Epoch 21/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 611ms/step - accuracy: 0.9042 - f1_score: 0.9151 - loss: 0.2218 - val_accuracy: 0.6250 - val_f1_score: 0.5761 - val_loss: 1.7100
# Epoch 22/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.8786 - f1_score: 0.8798 - loss: 0.2906
# Saved model with best validation accuracy: 0.9091
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 814ms/step - accuracy: 0.8785 - f1_score: 0.8798 - loss: 0.2894 - val_accuracy: 0.9091 - val_f1_score: 0.8756 - val_loss: 0.2709
# Epoch 23/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 617ms/step - accuracy: 0.9242 - f1_score: 0.9234 - loss: 0.1775 - val_accuracy: 0.6591 - val_f1_score: 0.6283 - val_loss: 3.1703
# Epoch 24/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 0.9067 - f1_score: 0.9000 - loss: 0.2570 - val_accuracy: 0.7273 - val_f1_score: 0.6848 - val_loss: 1.6773
# Epoch 25/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9072 - f1_score: 0.9055 - loss: 0.2281 - val_accuracy: 0.8750 - val_f1_score: 0.8500 - val_loss: 0.2894
# Epoch 26/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.9062 - f1_score: 0.8993 - loss: 0.2018 - val_accuracy: 0.8864 - val_f1_score: 0.8690 - val_loss: 0.3163
# Epoch 27/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.9133 - f1_score: 0.9075 - loss: 0.2578 - val_accuracy: 0.8068 - val_f1_score: 0.8294 - val_loss: 0.5583
# Epoch 28/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 609ms/step - accuracy: 0.9169 - f1_score: 0.8922 - loss: 0.2021 - val_accuracy: 0.7273 - val_f1_score: 0.7104 - val_loss: 1.8062
# Epoch 29/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 618ms/step - accuracy: 0.9331 - f1_score: 0.9250 - loss: 0.1682 - val_accuracy: 0.5909 - val_f1_score: 0.5802 - val_loss: 1.1829
# Epoch 30/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9406 - f1_score: 0.9377 - loss: 0.1741 - val_accuracy: 0.2500 - val_f1_score: 0.2411 - val_loss: 5.4129
# Epoch 31/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9226 - f1_score: 0.9130 - loss: 0.1730 - val_accuracy: 0.4432 - val_f1_score: 0.4384 - val_loss: 3.6245
# Epoch 32/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 0.9634 - f1_score: 0.9599 - loss: 0.1045 - val_accuracy: 0.3636 - val_f1_score: 0.3735 - val_loss: 3.7153
# Epoch 33/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 606ms/step - accuracy: 0.9072 - f1_score: 0.8668 - loss: 0.2162 - val_accuracy: 0.6818 - val_f1_score: 0.6606 - val_loss: 1.1317
# Epoch 34/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 607ms/step - accuracy: 0.9557 - f1_score: 0.9483 - loss: 0.1058 - val_accuracy: 0.8750 - val_f1_score: 0.8375 - val_loss: 0.3382
# Epoch 35/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 615ms/step - accuracy: 0.9605 - f1_score: 0.9586 - loss: 0.1003 - val_accuracy: 0.7159 - val_f1_score: 0.6889 - val_loss: 1.0091
# Epoch 36/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 618ms/step - accuracy: 0.9374 - f1_score: 0.9406 - loss: 0.1232 - val_accuracy: 0.4659 - val_f1_score: 0.4716 - val_loss: 3.2334
# Epoch 37/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 617ms/step - accuracy: 0.9589 - f1_score: 0.9501 - loss: 0.1386 - val_accuracy: 0.3068 - val_f1_score: 0.2987 - val_loss: 8.6012
# Epoch 38/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 617ms/step - accuracy: 0.8936 - f1_score: 0.8808 - loss: 0.2142 - val_accuracy: 0.6932 - val_f1_score: 0.6856 - val_loss: 1.5931
# Epoch 39/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.9593 - f1_score: 0.9549 - loss: 0.1293
# Saved model with best validation accuracy: 0.9773
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 810ms/step - accuracy: 0.9589 - f1_score: 0.9545 - loss: 0.1307 - val_accuracy: 0.9773 - val_f1_score: 0.9829 - val_loss: 0.0966
# Epoch 40/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 609ms/step - accuracy: 0.9727 - f1_score: 0.9752 - loss: 0.0930 - val_accuracy: 0.9205 - val_f1_score: 0.9252 - val_loss: 0.1709
# Epoch 41/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9570 - f1_score: 0.9502 - loss: 0.1025 - val_accuracy: 0.9545 - val_f1_score: 0.9524 - val_loss: 0.1355
# Epoch 42/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.9631 - f1_score: 0.9604 - loss: 0.0893 - val_accuracy: 0.8182 - val_f1_score: 0.8390 - val_loss: 0.5262
# Epoch 43/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 614ms/step - accuracy: 0.9810 - f1_score: 0.9844 - loss: 0.0794 - val_accuracy: 0.7045 - val_f1_score: 0.7283 - val_loss: 1.7451
# Epoch 44/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.9714 - f1_score: 0.9788 - loss: 0.0757 - val_accuracy: 0.9318 - val_f1_score: 0.9459 - val_loss: 0.2510
# Epoch 45/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.9736 - f1_score: 0.9796 - loss: 0.0617 - val_accuracy: 0.9773 - val_f1_score: 0.9814 - val_loss: 0.0784
# Epoch 46/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 0.9623 - f1_score: 0.9603 - loss: 0.0691 - val_accuracy: 0.9545 - val_f1_score: 0.9309 - val_loss: 0.2174
# Epoch 47/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 618ms/step - accuracy: 0.9699 - f1_score: 0.9541 - loss: 0.0935 - val_accuracy: 0.7614 - val_f1_score: 0.7992 - val_loss: 1.4090
# Epoch 48/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.9856 - f1_score: 0.9887 - loss: 0.0731 - val_accuracy: 0.9318 - val_f1_score: 0.9179 - val_loss: 0.2798
# Epoch 49/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 614ms/step - accuracy: 0.9723 - f1_score: 0.9619 - loss: 0.0615 - val_accuracy: 0.9545 - val_f1_score: 0.9515 - val_loss: 0.1338
# Epoch 50/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 607ms/step - accuracy: 0.9619 - f1_score: 0.9660 - loss: 0.0799 - val_accuracy: 0.9773 - val_f1_score: 0.9813 - val_loss: 0.0494
# Epoch 51/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 609ms/step - accuracy: 0.9861 - f1_score: 0.9848 - loss: 0.0376 - val_accuracy: 0.7159 - val_f1_score: 0.6430 - val_loss: 1.7342
# Epoch 52/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9510 - f1_score: 0.9208 - loss: 0.1268
# Saved model with best validation accuracy: 0.9886
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 832ms/step - accuracy: 0.9511 - f1_score: 0.9216 - loss: 0.1273 - val_accuracy: 0.9886 - val_f1_score: 0.9913 - val_loss: 0.0774
# Epoch 53/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.9601 - f1_score: 0.9615 - loss: 0.0854 - val_accuracy: 0.8409 - val_f1_score: 0.7769 - val_loss: 0.4279
# Epoch 54/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9477 - f1_score: 0.9429 - loss: 0.1009 - val_accuracy: 0.9091 - val_f1_score: 0.8864 - val_loss: 0.2431
# Epoch 55/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9765 - f1_score: 0.9776 - loss: 0.0630 - val_accuracy: 0.7841 - val_f1_score: 0.7401 - val_loss: 0.9908
# Epoch 56/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.9899 - f1_score: 0.9920 - loss: 0.0337 - val_accuracy: 0.9773 - val_f1_score: 0.9714 - val_loss: 0.0854
# Epoch 57/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 608ms/step - accuracy: 0.9779 - f1_score: 0.9751 - loss: 0.0446 - val_accuracy: 0.9659 - val_f1_score: 0.9637 - val_loss: 0.1191
# Epoch 58/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 610ms/step - accuracy: 0.9853 - f1_score: 0.9881 - loss: 0.0288 - val_accuracy: 0.9432 - val_f1_score: 0.9048 - val_loss: 0.1366
# Epoch 59/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 615ms/step - accuracy: 0.9920 - f1_score: 0.9923 - loss: 0.0255 - val_accuracy: 0.9886 - val_f1_score: 0.9917 - val_loss: 0.0364
# Epoch 60/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 613ms/step - accuracy: 0.9961 - f1_score: 0.9970 - loss: 0.0191 - val_accuracy: 0.9773 - val_f1_score: 0.9727 - val_loss: 0.0495
# Epoch 61/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9971 - f1_score: 0.9978 - loss: 0.0138 - val_accuracy: 0.9773 - val_f1_score: 0.9833 - val_loss: 0.0616
# Epoch 62/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 611ms/step - accuracy: 0.9931 - f1_score: 0.9909 - loss: 0.0183 - val_accuracy: 0.9432 - val_f1_score: 0.9564 - val_loss: 0.1627
# Epoch 63/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.9974 - f1_score: 0.9979 - loss: 0.0149 - val_accuracy: 0.9886 - val_f1_score: 0.9919 - val_loss: 0.0246
# Epoch 64/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.9957 - f1_score: 0.9929 - loss: 0.0097
# Saved model with best validation accuracy: 1.0000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 911ms/step - accuracy: 0.9955 - f1_score: 0.9927 - loss: 0.0099 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0045
# Epoch 65/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0094 - val_accuracy: 0.9886 - val_f1_score: 0.9910 - val_loss: 0.0208
# Epoch 66/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 616ms/step - accuracy: 0.9843 - f1_score: 0.9775 - loss: 0.1076 - val_accuracy: 0.3750 - val_f1_score: 0.3555 - val_loss: 8.2629
# Epoch 67/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 610ms/step - accuracy: 0.9727 - f1_score: 0.9682 - loss: 0.0664 - val_accuracy: 0.3977 - val_f1_score: 0.3913 - val_loss: 5.0440
# Epoch 68/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 612ms/step - accuracy: 0.9878 - f1_score: 0.9837 - loss: 0.0377 - val_accuracy: 0.8977 - val_f1_score: 0.8608 - val_loss: 0.2868
# Epoch 69/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 621ms/step - accuracy: 0.9719 - f1_score: 0.9792 - loss: 0.0455 - val_accuracy: 0.9886 - val_f1_score: 0.9821 - val_loss: 0.0445
# Epoch 70/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 615ms/step - accuracy: 0.9923 - f1_score: 0.9941 - loss: 0.0313 - val_accuracy: 0.9773 - val_f1_score: 0.9671 - val_loss: 0.0794
# Epoch 71/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.9963 - f1_score: 0.9929 - loss: 0.0158 - val_accuracy: 0.9886 - val_f1_score: 0.9911 - val_loss: 0.0143
# Epoch 72/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 609ms/step - accuracy: 0.9734 - f1_score: 0.9708 - loss: 0.0893 - val_accuracy: 0.8182 - val_f1_score: 0.7913 - val_loss: 0.4637
# Epoch 73/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 609ms/step - accuracy: 0.9803 - f1_score: 0.9847 - loss: 0.0547 - val_accuracy: 0.5795 - val_f1_score: 0.5524 - val_loss: 2.6013
# Epoch 74/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 614ms/step - accuracy: 0.9766 - f1_score: 0.9829 - loss: 0.0365 - val_accuracy: 0.7159 - val_f1_score: 0.6897 - val_loss: 1.3160
# Epoch 75/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 614ms/step - accuracy: 0.9908 - f1_score: 0.9783 - loss: 0.0291 - val_accuracy: 0.9773 - val_f1_score: 0.9715 - val_loss: 0.0558
# Epoch 76/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 615ms/step - accuracy: 0.9968 - f1_score: 0.9975 - loss: 0.0096 - val_accuracy: 0.9886 - val_f1_score: 0.9821 - val_loss: 0.0231
# Epoch 77/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 611ms/step - accuracy: 0.9979 - f1_score: 0.9983 - loss: 0.0082 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0024
# Epoch 78/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 610ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0069
# Epoch 79/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0017
# Epoch 80/80
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 615ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 9.3157e-04

# %%
import matplotlib.pyplot as plt

# กราฟ Loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])  # กำหนดค่าสูงสุดของแกน y เป็น 1
plt.legend()

# กราฟ Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])  # กำหนดค่าสูงสุดของแกน y เป็น 1
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras.models import load_model

def evaluate_model(model, test_ds):
    # Get predictions
    y_pred = []
    y_true = []
    for batch in test_ds:
        batch_pred = model.predict(batch[0])
        y_pred.extend(np.argmax(batch_pred, axis=1))
        y_true.extend(np.argmax(batch[1], axis=1))

    # Calculate F1-score
    f1 = f1_score(y_true, y_pred, average='weighted')
    print(f"Weighted F1-score: {f1:.4f}")

    # Calculate confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

    return f1, cm


# Load the best model, providing custom objects
best_model_path = 'best_model.weights.h5'
custom_objects = {'BertLayer': BertLayer, 'TFBertModel': TFBertModel}  # Add TFBertModel

# Recreate the model with the same architecture used during training
model = simplified_multimodal_model(img_height, img_width, max_length, num_classes)

# Compile the model before loading weights
model.compile(
    optimizer='adam',  # Use the same optimizer as during training
    loss='categorical_crossentropy',  # Use the same loss function as during training
    metrics=['accuracy', F1Score()]
)

# Load the weights into the recreated model, providing custom objects
model.load_weights(best_model_path)

# Evaluate the model
f1_score, conf_matrix = evaluate_model(model, test_ds)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 994 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 27s 27s/step
# Weighted F1-score: 1.0000
# Confusion Matrix:
# [[38  0  0]
#  [ 0 35  0]
#  [ 0  0 17]]
